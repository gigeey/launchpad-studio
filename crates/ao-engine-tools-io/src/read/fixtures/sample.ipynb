# %% [markdown]
# # Sample Notebook
#
# A short demonstration notebook used as a test fixture.

# %%
x = 6 * 7
print(x)
# Out:
# 42

# %%
result = x + 1
result
# Out:
# 43

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 1 / 0
# ZeroDivisionError: division by zero

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3])
